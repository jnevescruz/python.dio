# %%
print("Ola Mundo")
# Out:
# Ola Mundo

# %%
print("Estou aprendendo Python")
# Out:
# Estou aprendendo Python

# %%
"Estou aprendendo Python"
# Out:
# 'Estou aprendendo Python'

# %%
1+1
# Out:
# 2

# %%
#Esse é um comentario em python

# %%
#Multiplição
2*2
# Out:
# 4
